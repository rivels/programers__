# %% [markdown]
# ###  정규표현식 : regex
# - 문자열 테이터를 처리할때, 특정한 패턴으로 문자열 데이터를 처리하는 방법.
# - 정규표현식 함수 : findall, sub
#     - findall : 패턴에 맞는 문자열을 찾는 함수
#     - sub : 패턴에 맞는 문자열을 찾아서 특정 문자열로 치환
# - pattern
#     - 문자
#     - 지정자
#
# - 예시
#     - 이메일 주소 찾아내기
#     - 주민등록번호 찾아서 치환하기
#     - 중고나라 전화번호

# %%
import re

# %%
#1.정규표현식 함수

# %%
data = "fast campus jupyter notebook notecamp python"

# %%
# findall
re.findall("note[a-z]{4}",data)
# Out:
# ['notebook', 'notecamp']

# %%
# sub 
re.sub('note([a-z]{4})',"\g<1>macbook",data)
# Out:
# 'fast campus jupyter bookmacbook campmacbook python'

# %%
# 문자 패턴

# %%
import string

# %%
data = string.printable
len(data), data
# Out:
# (100,
#  '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c')

# %% [markdown]
# # \d : 숫자
# # \D : 비 숫자

# %%
result = re.findall("\d",data)
"".join(result)

# %%
"".join(result)
# Out:
# '0123456789'

# %%
result = re.findall("\D",data)
"".join(result)
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %% [markdown]
# # \w : 숫자, 문자, _ 를 찾는다
# # \W : 숫자, 문자, _를 제외한 나머지를 찾는다

# %%
result = re.findall("\w",data)
"".join(result)
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ_'

# %%
result = re.findall("\W",data)
"".join(result)
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^`{|}~ \t\n\r\x0b\x0c'

# %% [markdown]
# # \s : 공백문자
# # \S : 비공백문자

# %%
result = re.findall("\s",data)
"".join(result)
# Out:
# ' \t\n\r\x0b\x0c'

# %%
result = re.findall("\S",data)
"".join(result)
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# # 3. 지정자

# %% [markdown]
# # [ ] : 문자 하나를 의미함

# %%
data = "fastcampus"

# %%
re.findall("fast",data)
# Out:
# ['fast']

# %%
re.findall("[fast]",data) #[]안에 있는 문자 하나하나를 모두 각각 찾음 마지막 a s campus의 a 와 s 임
# Out:
# ['f', 'a', 's', 't', 'a', 's']

# %%
data = string.printable

# %% [markdown]
# # - : 범위지정자
# - 말그대로 범위를 지정할 수 있음

# %%
data
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
re.findall("[012345]", data)
# Out:
# ['0', '1', '2', '3', '4', '5']

# %%
re.findall("[0-5]", data)
# Out:
# ['0', '1', '2', '3', '4', '5']

# %%
re.findall("[0-2 a-f x-z A-C]", data)
# Out:
# ['0', '1', '2', 'a', 'b', 'c', 'd', 'e', 'f', 'x', 'y', 'z', 'A', 'B', 'C']

# %% [markdown]
# # . : 아무문자 하나

# %%
data1, data2, data3 = "abc", "ac", "a c"

# %%
re.findall("a.c",data1),re.findall("a.c",data2),re.findall("a.c",data3)
# Out:
# (['abc'], [], ['a c'])

# %%
data4 = "a\.c"  #아무문자 하나라는 뜻이아니라 'a.c'라는 그 자체를 찾고싶을땐 앞에 \를 붙이면 됨
re.findall("a[.]c", data) #혹은 .을 []안에 가두면 문자 그자체로 인식하게됨
# Out:
# []

# %% [markdown]
# # ? : ? 앞에 있는 패턴을 0 또는 1회 반복해줌

# %%
data1, data2, data3 = "abc", "ac", "abbc"
re.findall("a.?c",data1),re.findall("a.?c",data2),re.findall("a.?c",data3)
# Out:
# (['abc'], ['ac'], [])

# %% [markdown]
# # * : 0회 이상 반복

# %%
data1, data2, data3 = "abc", "ac", "abbc"
re.findall("a.*c",data1),re.findall("a.*c",data2),re.findall("a.*c",data3)
# Out:
# (['abc'], ['ac'], ['abbc'])

# %% [markdown]
# # + : 1회 이상 반복

# %%
data1, data2, data3 = "abc", "ac", "abbc"
re.findall("a.+c",data1),re.findall("a.+c",data2),re.findall("a.+c",data3)
# Out:
# (['abc'], [], ['abbc'])

# %% [markdown]
# # {n} : n회 반복
# # {n,m} : n~m회 반복

# %%
data1 = "abbc abbbbc abbbbbbc"
re.findall("a.{2}c",data1),re.findall("a.{1,4}c",data1),re.findall("a.{3,7}c",data1)
# Out:
# (['abbc'], ['abbc', 'abbbbc'], ['abbbbc', 'abbbbbbc'])

# %% [markdown]
# # () : 그룹핑
# ## 패턴으로 문자열을 찾는데 ()안에 있는 문자열만 출력

# %%
data = "저의 전화번호는 010-1111-2222 나 011-222-4444입니다."

# %%
re.findall("[0-9]{3}[-]?[0-9]{3,4}[-]?[0-9]{4}",data)
# Out:
# ['010-1111-2222', '011-222-4444']

# %%
re.findall("([0-9]{3})[-]?[0-9]{3,4}[-]?[0-9]{4}",data) 
# ()로 가둬서 출력하고싶은 부분만 추려낼 수 있음
# Out:
# ['010', '011']

# %%
# example

# %%
# email 주소찾기

# %%
data = "저의 이메일 주소는 fast.campus@fc.com 이고 data@naver.co.kr 입니다"

# %%
re.findall(pt,data)
# Out:
# ['fc.com', 'naver.co.kr']

# %%
pt = "[0-9a-zA-Z.]+@[a-z]+[a-z.]+"

# %%
re.findall(pt,data)
# Out:
# ['fast.campus@fc.com', 'data@naver.co.kr']

# %%
# 주민등록번호 찾아서 치환하기

# %%
data = '저의 주민등록번호는 761232-1089913 입니다 언제나 사용하세요'

# %%
re.findall('[0-9]+-[0-9]+',data)
# Out:
# ['761232-1089913']

# %%
re.findall('[0-9]{2}[01][0-9][0-3][0-9]-?[1-4][0-9]{6}',data)
# Out:
# ['761232-1089913']

# %%
data = '저의 주민등록번호는 761232-1089913 입니다 언제나 사용하세요'
pt = '[0-9]{2}[01][0-9][0-3][0-9]-?[1-4][0-9]{6}'
re.findall(pt,data)
re.sub(pt, "\g<1>-*******", data)
re.sub(pt, "******-\g<2>", data)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-105-d258276969ce> in <module>
#       2 pt = '[0-9]{2}[01][0-9][0-3][0-9]-?[1-4][0-9]{6}'
#       3 re.findall(pt,data)
# ----> 4 re.sub(pt, "\g<1>-*******", data)
#       5 re.sub(pt, "******-\g<2>", data)
#
# ~/opt/anaconda3/lib/python3.8/re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# ~/opt/anaconda3/lib/python3.8/re.py in _subx(pattern, template)
#     325 def _subx(pattern, template):
#     326     # internal: Pattern.sub/subn implementation helper
# --> 327     template = _compile_repl(template, pattern)
#     328     if not template[0] and len(template[1]) == 1:
#     329         # literal replacement
#
# ~/opt/anaconda3/lib/python3.8/re.py in _compile_repl(repl, pattern)
#     316 def _compile_repl(repl, pattern):
#     317     # internal: compile replacement pattern
# --> 318     return sre_parse.parse_template(repl, pattern)
#     319
#     320 def _expand(pattern, match, template):
#
# ~/opt/anaconda3/lib/python3.8/sre_parse.py in parse_template(source, state)
#    1013                         raise s.error("invalid group reference %d" % index,
#    1014                                       len(name) + 1)
# -> 1015                 addgroup(index, len(name) + 1)
#    1016             elif c == "0":
#    1017                 if s.next in OCTDIGITS:
#
# ~/opt/anaconda3/lib/python3.8/sre_parse.py in addgroup(index, pos)
#     978     def addgroup(index, pos):
#     979         if index > state.groups:
# --> 980             raise s.error("invalid group reference %d" % index, pos)
#     981         if literal:
#     982             literals.append(''.join(literal))
#
# error: invalid group reference 1 at position 3

# %%
# 전화번호 문자열 변경하기

# %%
data = "안녕하세요 플스4 20000원에 급처 합니다. 선착순 연락주세요 전화번호는 01O-사구빵빵-구79삼과 영일영삼312공구00 중에 연락 주세요"

# %%
pt = "\w{3}-?\w{4}-?\w{4}"
numbers = re.findall(pt,data)

# %%
change_number ={
    "영": 0,
    "공" : 0,
    "빵" : 0,
    "일" : 1,
    "이" : 2, "삼" : 3, "사":4, "오":5 ,"육" : 6, "칠":7 ,"팔":8, "구":9, "O" :0, 'o' : 0
}

# %%
result = []
for number in numbers:
    print(number)
    for key, value in change_number.items():
        number = number.replace(key,str(value))
    result.append(number.replace("-",""))
print(result)
# Out:
# 01O-사구빵빵-구79삼
# 영일영삼312공구00
# ['01049009793', '01033120900']
